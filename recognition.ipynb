# %%
import tensorflow as tf
from tensorflow.keras import layers, models

# %%
PATH_DATA = 'dataset'
train_ds = tf.keras.utils.image_dataset_from_directory(PATH_DATA, validation_split=0.2, subset='training', seed=123, image_size=(28, 28), batch_size=32)
validation_ds = tf.keras.utils.image_dataset_from_directory(PATH_DATA, validation_split=0.2, subset='validation', seed=123, image_size=(28, 28), batch_size=32)
# Out:
# Found 107730 files belonging to 10 classes.
# Using 86184 files for training.
# Found 107730 files belonging to 10 classes.
# Using 21546 files for validation.

# %%
model = models.Sequential([
    layers.Conv2D(32, 3, activation='relu'),
    layers.MaxPooling2D(pool_size=(2)),
    layers.Conv2D(32, 3, activation='relu'),
    layers.MaxPooling2D(pool_size=(2))
])
